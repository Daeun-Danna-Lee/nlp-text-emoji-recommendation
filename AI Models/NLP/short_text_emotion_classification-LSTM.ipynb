# %% [markdown]
# <a href="https://colab.research.google.com/github/Daeun-Danna-Lee/NLP-Sentiment-Classification/blob/main/Movie_Review_Sentiment_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 이다은/2019312492/0.828

# %% [markdown]
# ### 개발 환경
#
# - 애플 실리콘(M1) 맥북
# - macOS Big Sur 12.0.1
# - python 3.7.12
# - google colab

# %%
# !conda install scikit-learn

# %%
# %pip install -U scikit-learn

# %%
# !pip install konlpy

# %%
# !pip install tensorflow

# %%
import sys

print(sys.version)
# Out:
# 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %%
import pandas as pd
import sklearn
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터 불러오기

data = pd.read_csv('./processed_data', sep=',', names=['발화문', '평균감정'])
data
# Out:
#                              발화문  평균감정
# 0               어, 청소 니가 대신 해 줘!   4.0
# 1             둘 다 청소 하기 싫어. 귀찮아.   4.0
# 2                 둘 다 하기 싫어서 화내.   1.0
# 3                    그럼 방세는 어떡해.   5.0
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.   5.0
# ...                          ...   ...
# 43986              나 엘리베이터에 갇혔어.   5.0
# 43987          하지만 기분이 나쁜 걸 어떡해?   5.0
# 43988          자취방 엘리베이턴데 정전인가봐.   5.0
# 43989            나 드디어 프로젝트 끝났어!   5.0
# 43990                 걱정해줘서 고마워.   4.0
#
# [43991 rows x 2 columns]

# %%
# 구둣점 제거 -> 공백으로 대체
data['발화문'] = data['발화문'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z]"," ")

# %%
data
# Out:
#                              발화문  평균감정
# 0               어  청소 니가 대신 해 줘    4.0
# 1             둘 다 청소 하기 싫어  귀찮아    4.0
# 2                 둘 다 하기 싫어서 화내    1.0
# 3                    그럼 방세는 어떡해    5.0
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고    5.0
# ...                          ...   ...
# 43986              나 엘리베이터에 갇혔어    5.0
# 43987          하지만 기분이 나쁜 걸 어떡해    5.0
# 43988          자취방 엘리베이턴데 정전인가봐    5.0
# 43989            나 드디어 프로젝트 끝났어    5.0
# 43990                 걱정해줘서 고마워    4.0
#
# [43991 rows x 2 columns]

# %%
# train, test data 분리

from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(data, test_size = 0.3)

# %%
train_df.shape
# Out:
# (30793, 2)

# %%
print(train_df.isnull().values.any()) # 데이터에 null 값이 있는지 검사 (있으면 True 반환)
# Out:
# False

# %%
# stopwords 정의 (https://www.ranks.nl/stopwords/korean)

stopwords = ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해', '을', '를', '에', '의', '가', '으로', '로', '에게', '뿐이다', '의거하여', '근거하여', '입각하여', '기준으로', '예하면', '예를 들면', '예를 들자면', '저', '소인', '소생', '저희', '지말고', '하지마', '하지마라', '다른', '물론', '또한', '그리고', '비길수 없다', '해서는 안된다', '뿐만 아니라', '만이 아니다', '만은 아니다', '막론하고', '관계없이', '그치지 않다', '그러나', '그런데', '하지만', '든간에', '논하지 않다', '따지지 않다', '설사', '비록', '더라도', '아니면', '만 못하다', '하는 편이 낫다', '불문하고', '향하여', '향해서', '향하다', '쪽으로', '틈타', '이용하여', '타다', '오르다', '제외하고', '이 외에', '이 밖에', '하여야', '비로소', '한다면 몰라도', '외에도', '이곳', '여기', '부터', '기점으로', '따라서', '할 생각이다', '하려고하다', '이리하여', '그리하여', '그렇게 함으로써', '하지만', '일때', '할때', '앞에서', '중에서', '보는데서', '으로써', '로써', '까지', '해야한다', '일것이다', '반드시', '할줄알다', '할수있다', '할수있어', '임에 틀림없다', '한다면', '등', '등등', '제', '겨우', '단지', '다만', '할뿐', '딩동', '댕그', '대해서', '대하여', '대하면', '훨씬', '얼마나', '얼마만큼', '얼마큼', '남짓', '여', '얼마간', '약간', '다소', '좀', '조금', '다수', '몇', '얼마', '지만', '하물며', '또한', '그러나', '그렇지만', '하지만', '이외에도', '대해 말하자면', '뿐이다', '다음에', '반대로', '반대로 말하자면', '이와 반대로', '바꾸어서 말하면', '바꾸어서 한다면', '만약', '그렇지않으면', '까악', '툭', '딱', '삐걱거리다', '보드득', '비걱거리다', '꽈당', '응당', '해야한다', '에 가서', '각', '각각', '여러분', '각종', '각자', '제각기', '하도록하다', '와', '과', '그러므로', '그래서', '고로', '한 까닭에', '하기 때문에', '거니와', '이지만', '대하여', '관하여', '관한', '과연', '실로', '아니나다를가', '생각한대로', '진짜로', '한적이있다', '하곤하였다', '하', '하하', '허허', '아하', '거바', '와', '오', '왜', '어째서', '무엇때문에', '어찌', '하겠는가', '무슨', '어디', '어느곳', '더군다나', '하물며', '더욱이는', '어느때', '언제', '야', '이봐', '어이', '여보시오', '흐흐', '흥', '휴', '헉헉', '헐떡헐떡', '영차', '여차', '어기여차', '끙끙', '아야', '앗', '아야', '콸콸', '졸졸', '좍좍', '뚝뚝', '주룩주룩', '솨', '우르르', '그래도', '또', '그리고', '바꾸어말하면', '바꾸어말하자면', '혹은', '혹시', '답다', '및', '그에 따르는', '때가 되어', '즉', '지든지', '설령', '가령', '하더라도', '할지라도', '일지라도', '지든지', '몇', '거의', '하마터면', '인젠', '이젠', '된바에야', '된이상', '만큼어찌됏든', '그위에', '게다가', '점에서 보아', '비추어 보아', '고려하면', '하게될것이다', '일것이다', '비교적', '좀', '보다더', '비하면', '시키다', '하게하다', '할만하다', '의해서', '연이서', '이어서', '잇따라', '뒤따라', '뒤이어', '결국', '의지하여', '기대여', '통하여', '자마자', '더욱더', '불구하고', '얼마든지', '마음대로', '주저하지 않고', '곧', '즉시', '바로', '당장', '하자마자', '밖에 안된다', '하면된다', '그래', '그렇지', '요컨대', '다시 말하자면', '바꿔 말하면', '즉', '구체적으로', '말하자면', '시작하여', '시초에', '이상', '허', '헉', '허걱', '바와같이', '해도좋다', '해도된다', '게다가', '더구나', '하물며', '와르르', '팍', '퍽', '펄렁', '동안', '이래', '하고있었다', '이었다', '에서', '로부터', '까지', '예하면', '했어요', '해요', '함께', '같이', '더불어', '마저', '마저도', '양자', '모두', '습니다', '가까스로', '하려고하다', '즈음하여', '다른', '다른 방면으로', '해봐요', '습니까', '했어요', '말할것도 없고', '무릎쓰고', '개의치않고', '하는것만 못하다', '하는것이 낫다', '매', '매번', '들', '모', '어느것', '어느', '로써', '갖고말하자면', '어디', '어느쪽', '어느것', '어느해', '어느 년도', '라 해도', '언젠가', '어떤것', '어느것', '저기', '저쪽', '저것', '그때', '그럼', '그러면', '요만한걸', '그래', '그때', '저것만큼', '그저', '이르기까지', '할 줄 안다', '할 힘이 있다', '너', '너희', '당신', '어찌', '설마', '차라리', '할지언정', '할지라도', '할망정', '할지언정', '구토하다', '게우다', '토하다', '메쓰겁다', '옆사람', '퉤', '쳇', '의거하여', '근거하여', '의해', '따라', '힘입어', '그', '다음', '버금', '두번째로', '기타', '첫번째로', '나머지는', '그중에서', '견지에서', '형식으로 쓰여', '입장에서', '위해서', '단지', '의해되다', '하도록시키다', '뿐만아니라', '반대로', '전후', '전자', '앞의것', '잠시', '잠깐', '하면서', '그렇지만', '다음에', '그러한즉', '그런즉', '남들', '아무거나', '어찌하든지', '같다', '비슷하다', '예컨대', '이럴정도로', '어떻게', '만약', '만일', '위에서 서술한바와같이', '인 듯하다', '하지 않는다면', '만약에', '무엇', '무슨', '어느', '어떤', '아래윗', '조차', '한데', '그럼에도 불구하고', '여전히', '심지어', '까지도', '조차도', '하지 않도록', '않기 위하여', '때', '시각', '무렵', '시간', '동안', '어때', '어떠한', '하여금', '네', '예', '우선', '누구', '누가 알겠는가', '아무도', '줄은모른다', '줄은 몰랏다', '하는 김에', '겸사겸사', '하는바', '그런 까닭에', '한 이유는', '그러니', '그러니까', '때문에', '그', '너희', '그들', '너희들', '타인', '것', '것들', '너', '위하여', '공동으로', '동시에', '하기 위하여', '어찌하여', '무엇때문에', '붕붕', '윙윙', '나', '우리', '엉엉', '휘익', '윙윙', '오호', '아하', '어쨋든', '만 못하다하기보다는', '차라리', '하는 편이 낫다', '흐흐', '놀라다', '상대적으로 말하자면', '마치', '아니라면', '쉿', '그렇지 않으면', '그렇지 않다면', '안 그러면', '아니었다면', '하든지', '아니면', '이라면', '좋아', '알았어', '하는것도', '그만이다', '어쩔수 없다', '하나', '일', '일반적으로', '일단', '한켠으로는', '오자마자', '이렇게되면', '이와같다면', '전부', '한마디', '한항목', '근거로', '하기에', '아울러', '하지 않도록', '않기 위해서', '이르기까지', '이 되다', '로 인하여', '까닭으로', '이유만으로', '이로 인하여', '그래서', '이 때문에', '그러므로', '그런 까닭에', '알 수 있다', '결론을 낼 수 있다', '으로 인하여', '있다', '어떤것', '관계가 있다', '관련이 있다', '연관되다', '어떤것들', '에 대해', '이리하여', '그리하여', '여부', '하기보다는', '하느니', '하면 할수록', '운운', '이러이러하다', '하구나', '하도다', '다시말하면', '다음으로', '에 있다', '에 달려 있다', '우리', '우리들', '오히려', '하기는한데', '어떻게', '어떻해', '어찌됏어', '어때', '어째서', '본대로', '자', '이', '이쪽', '여기', '이것', '이번', '이렇게말하자면', '이런', '이러한', '이와 같은', '요만큼', '요만한 것', '얼마 안 되는 것', '이만큼', '이 정도의', '이렇게 많은 것', '이와 같다', '이때', '이렇구나', '것과 같이', '끼익', '삐걱', '따위', '와 같은 사람들', '부류의 사람들', '왜냐하면', '중의하나', '오직', '오로지', '에 한하다', '하기만 하면', '도착하다', '까지 미치다', '도달하다', '정도에 이르다', '할 지경이다', '결과에 이르다', '관해서는', '여러분', '하고 있다', '한 후', '혼자', '자기', '자기집', '자신', '우에 종합한것과같이', '총적으로 보면', '총적으로 말하면', '총적으로', '대로 하다', '으로서', '참', '그만이다', '할 따름이다', '쿵', '탕탕', '쾅쾅', '둥둥', '봐', '봐라', '아이야', '아니', '와아', '응', '아이', '참나', '년', '월', '일', '령', '영', '일', '이', '삼', '사', '오', '육', '륙', '칠', '팔', '구', '이천육', '이천칠', '이천팔', '이천구', '하나', '둘', '셋', '넷', '다섯', '여섯', '일곱', '여덟', '아홉', '령', '영']

# %%
# 토큰화

from nltk.tokenize import word_tokenize
from konlpy.tag import Kkma, Okt
from konlpy.tag import Okt
from tqdm import tqdm

train_text = []
test_text = []

okt = Okt()
for text in tqdm(train_df['발화문']):
  temp = okt.morphs(text, stem=True) # 형태소 기준 토큰화, 원형으로 변형
  no_stopwords_ver = [word for word in temp if not word in stopwords] # 스탑워드 제거
  train_text.append(no_stopwords_ver)
for text in tqdm(test_df['발화문']):
  temp = okt.morphs(text, stem=True)
  no_stopwords_ver = [word for word in temp if not word in stopwords]
  test_text.append(no_stopwords_ver)
train_label = train_df['평균감정']
test_label = test_df['평균감정']
# Out:
# 100%|██████████| 30793/30793 [00:57<00:00, 531.37it/s]
# 100%|██████████| 13198/13198 [00:20<00:00, 632.73it/s]

# %%
# 정수 인코딩

from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_text)

# %%
print(tokenizer.word_index)
# Out:
# {'하다': 1, '너무': 2, '도': 3, '안': 4, '없다': 5, '그렇다': 6, '내': 7, '오다': 8, '은': 9, '좋다': 10, '돼다': 11, '거': 12, '보다': 13, '는': 14, '되다': 15, '친구': 16, '아니다': 17, '않다': 18, '못': 19, '지금': 20, '사람': 21, '들다': 22, '정말': 23, '집': 24, '자다': 25, '나다': 26, '가다': 27, '힘들다': 28, '많이': 29, '어제': 30, '다': 31, '모르다': 32, '다치다': 33, '한테': 34, '해피': 35, '약속': 36, '이야': 37, '먹다': 38, '만': 39, '회사': 40, '말': 41, '괜찮다': 42, '진짜': 43, '오늘': 44, '기분': 45, '고맙다': 46, '알다': 47, '해주다': 48, '생각': 49, '싶다': 50, '하고': 51, '애': 52, '더': 53, '청소': 54, '그냥': 55, '고': 56, '한': 57, '만나다': 58, '게': 59, '떨어지다': 60, '나가다': 61, '요즘': 62, '갑자기': 63, '맞다': 64, '이다': 65, '버리다': 66, '짜다': 67, '마음': 68, '무섭다': 69, '랑': 70, '싸우다': 71, '받다': 72, '아직': 73, '거야': 74, '새': 75, '많다': 76, '구경': 77, '어떻다': 78, '화장실': 79, '번': 80, '일이': 81, '해': 82, '우울하다': 83, '나오다': 84, '때문': 85, '술': 86, '연락': 87, '해보다': 88, '근데': 89, '뭐': 90, '엄청': 91, '면접': 92, '얘기': 93, '헤어지다': 94, '냄새': 95, '곰팡이': 96, '기다리다': 97, '걱정': 98, '몰리다': 99, '당첨': 100, '수': 101, '이제': 102, '이야기': 103, '주식': 104, '치우다': 105, '아프다': 106, '그렇게': 107, '병원': 108, '계속': 109, '아무': 110, '아빠': 111, '다시': 112, '서': 113, '자주': 114, '끝나다': 115, '시작': 116, '잘': 117, '내일': 118, '주다': 119, '허리': 120, '떠나다': 121, '퇴근': 122, '니까': 123, '밖에': 124, '아직도': 125, '라고': 126, '되어다': 127, '수가': 128, '궁금하다': 129, '전화': 130, '산책': 131, '음악': 132, '세상': 133, '달': 134, '정도': 135, '이벤트': 136, '토': 137, '밥': 138, '생기다': 139, '프로젝트': 140, '갇히다': 141, '다행하다': 142, '비': 143, '지': 144, '넘어지다': 145, '매일': 146, '에는': 147, '준비': 148, '난': 149, '가족': 150, '깜짝': 151, '마다': 152, '추천': 153, '갈다': 154, '쉬다': 155, '건': 156, '두': 157, '해봤다': 158, '해도': 159, '곳': 160, '이렇게': 161, '지진': 162, '인데': 163, '누가': 164, '저녁': 165, '기획': 166, '그대로': 167, '볼': 168, '늦다': 169, '쓰레기통': 170, '몸': 171, '짜증나다': 172, '바쁘다': 173, '좋아하다': 174, '아깝다': 175, '인': 176, '알': 177, '전': 178, '방': 179, '슬프다': 180, '보고': 181, '쓰레기': 182, '화가': 183, '고등학교': 184, '다녀오다': 185, '들어오다': 186, '드리다': 187, '새끼': 188, '가보다': 189, '한번': 190, '지다': 191, '휴가': 192, '속상하다': 193, '처음': 194, '놀래다': 195, '당연하다': 196, '없어지다': 197, '데': 198, '드디어': 199, '크다': 200, '유기견': 201, '명': 202, '말씀': 203, '룸메이트': 204, '코로나': 205, '막': 206, '다니다': 207, '날': 208, '자꾸': 209, '이나': 210, '적': 211, '사다': 212, '마라톤': 213, '갖다': 214, '더럽다': 215, '어떡하다': 216, '축하': 217, '맨날': 218, '싫다': 219, '벌써': 220, '부모님': 221, '내다': 222, '역겹다': 223, '살다': 224, '상사': 225, '벌레': 226, '기록': 227, '이지': 228, '룸메': 229, '진정': 230, '이랑': 231, '듣다': 232, '계단': 233, '음식물': 234, '일주일': 235, '빨리': 236, '살': 237, '답답하다': 238, '걸': 239, '죽다': 240, '말다': 241, '향수': 242, '그거': 243, '나아지다': 244, '항상': 245, '분': 246, '신나다': 247, '아무래도': 248, '짜장면': 249, '이렇다': 250, '여행': 251, '완전': 252, '넘다': 253, '문제': 254, '스트레스': 255, '권태기': 256, '일어나다': 257, '써다': 258, '지치다': 259, '일도': 260, '그게': 261, '한지': 262, '대로': 263, '진행': 264, '보': 265, '입원': 266, '짜증': 267, '대회': 268, '요새': 269, '새롭다': 270, '영화': 271, '사진': 272, '가지': 273, '줄이다': 274, '소개': 275, '줄': 276, '계시다': 277, '경찰': 278, '주변': 279, '노트북': 280, '찍다': 281, '물이': 282, '화': 283, '헐다': 284, '돈': 285, '밤': 286, '나서다': 287, '지나다': 288, '목': 289, '얼른': 290, '소리': 291, '꼭': 292, '들어가다': 293, '키우다': 294, '열심히': 295, '뽑다': 296, '별로': 297, '지장': 298, '앞': 299, '거기': 300, '물': 301, '구매': 302, '잘못': 303, '치다': 304, '엔': 305, '겠다': 306, '강아지': 307, '힘': 308, '고치다': 309, '방법': 310, '끊어지다': 311, '완전하다': 312, '생명': 313, '거제': 314, '미루다': 315, '며칠': 316, '장소': 317, '에도': 318, '힘드다': 319, '뛰다': 320, '야근': 321, '밖': 322, '발목': 323, '고민': 324, '그것': 325, '이르다': 326, '너무나': 327, '중이': 328, '망하다': 329, '치료': 330, '뭘': 331, '잡다': 332, '동창': 333, '운동': 334, '따로': 335, '달리다': 336, '효과': 337, '주': 338, '욕': 339, '방향': 340, '사과': 341, '지저분하다': 342, '강남역': 343, '오래': 344, '남다': 345, '마지막': 346, '사라지다': 347, '괜히': 348, '옮기다': 349, '일찍': 350, '의식': 351, '쓰다': 352, '안되다': 353, '쉬': 354, '서로': 355, '지인': 356, '들어서다': 357, '원래': 358, '강남': 359, '래': 360, '취미': 361, '선물': 362, '제출': 363, '으': 364, '확': 365, '풀리다': 366, '에만': 367, ...

# %%
threshold = 4
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 4276
# 등장 빈도가 3번 이하인 희귀 단어의 수: 2223
# 단어 집합에서 희귀 단어의 비율: 51.987839101964454
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.5117402580591475

# %%
# 전체 단어 개수 중 빈도수 threshold 이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 2054

# %%
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(train_text)
train_text = tokenizer.texts_to_sequences(train_text)
test_text = tokenizer.texts_to_sequences(test_text)

# %%
print(train_text[:3])
# Out:
# [[7, 303, 228], [199, 140, 516], [17, 175, 35, 131, 151]]

# %%
# 길이가 0인 샘플들의 인덱스
drop_train = [index for index, sentence in enumerate(train_text) if len(sentence) < 1]

# %%
# # 라벨 값을 숫자로 변경
# train_df["평균감정"] = train_df["평균감정"].astype(str).astype(int)
# test_df["평균감정"] = test_df["평균감정"].astype(str).astype(int)

# %%
# 라벨 데이터 업데이트
train_label = np.array(train_df['평균감정'])
test_label = np.array(test_df['평균감정'])

# %%
# 빈 샘플들을 제거
train_text = np.delete(train_text, drop_train, axis=0)
train_label = np.delete(train_label, drop_train, axis=0)
print(len(train_text))
print(len(train_label))
# Out:
# 30779
# 30779
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### 패딩

# %%
# 패딩

print('리뷰의 최대 길이 :',max(len(l) for l in train_text))
print('리뷰의 평균 길이 :',sum(map(len, train_text))/len(train_text))
plt.hist([len(s) for s in train_text], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 38
# 리뷰의 평균 길이 : 6.921504922187205

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 20
below_threshold_len(max_len, train_text)
# Out:
# 전체 샘플 중 길이가 20 이하인 샘플의 비율: 99.23974138211118

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

train_text = pad_sequences(train_text, maxlen = max_len)
test_text = pad_sequences(test_text, maxlen = max_len)

# %% [markdown]
# ### LSTM으로 학습하기

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 100
hidden_units = 128

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(LSTM(hidden_units))
model.add(Dense(1, activation='sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(train_text, train_label, epochs=100, callbacks=[es, mc], batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/100
# 385/385 [==============================] - ETA: 0s - loss: -1749.1635 - acc: 0.2250
# Epoch 00001: val_acc improved from 0.22547 to 0.23359, saving model to best_model.h5
# 385/385 [==============================] - 23s 52ms/step - loss: -1749.1635 - acc: 0.2250 - val_loss: -1795.8368 - val_acc: 0.2336
# Epoch 2/100
# 385/385 [==============================] - ETA: 0s - loss: -1860.3270 - acc: 0.2264
# Epoch 00002: val_acc improved from 0.23359 to 0.23489, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -1860.3270 - acc: 0.2264 - val_loss: -1908.9716 - val_acc: 0.2349
# Epoch 3/100
# 385/385 [==============================] - ETA: 0s - loss: -1972.3967 - acc: 0.2282
# Epoch 00003: val_acc improved from 0.23489 to 0.23912, saving model to best_model.h5
# 385/385 [==============================] - 19s 50ms/step - loss: -1972.3967 - acc: 0.2282 - val_loss: -2009.5830 - val_acc: 0.2391
# Epoch 4/100
# 385/385 [==============================] - ETA: 0s - loss: -2084.2319 - acc: 0.2291
# Epoch 00004: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2084.2319 - acc: 0.2291 - val_loss: -2129.9785 - val_acc: 0.2323
# Epoch 5/100
# 384/385 [============================>.] - ETA: 0s - loss: -2196.8420 - acc: 0.2290
# Epoch 00005: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2196.4336 - acc: 0.2291 - val_loss: -2239.5710 - val_acc: 0.2346
# Epoch 6/100
# 385/385 [==============================] - ETA: 0s - loss: -2308.0862 - acc: 0.2308
# Epoch 00006: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2308.0862 - acc: 0.2308 - val_loss: -2352.0920 - val_acc: 0.2214
# Epoch 7/100
# 385/385 [==============================] - ETA: 0s - loss: -2419.4431 - acc: 0.2309
# Epoch 00007: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2419.4431 - acc: 0.2309 - val_loss: -2461.3367 - val_acc: 0.2305
# Epoch 8/100
# 384/385 [============================>.] - ETA: 0s - loss: -2529.8005 - acc: 0.2311
# Epoch 00008: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2530.6228 - acc: 0.2310 - val_loss: -2572.7715 - val_acc: 0.2260
# Epoch 9/100
# 385/385 [==============================] - ETA: 0s - loss: -2642.1472 - acc: 0.2315
# Epoch 00009: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2642.1472 - acc: 0.2315 - val_loss: -2683.0134 - val_acc: 0.2253
# Epoch 10/100
# 384/385 [============================>.] - ETA: 0s - loss: -2754.8018 - acc: 0.2321
# Epoch 00010: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2754.6689 - acc: 0.2320 - val_loss: -2791.0786 - val_acc: 0.2333
# Epoch 11/100
# 384/385 [============================>.] - ETA: 0s - loss: -2866.1960 - acc: 0.2321
# Epoch 00011: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2866.2100 - acc: 0.2321 - val_loss: -2904.9482 - val_acc: 0.2302
# Epoch 12/100
# 385/385 [==============================] - ETA: 0s - loss: -2978.0093 - acc: 0.2322
# Epoch 00012: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -2978.0093 - acc: 0.2322 - val_loss: -3012.0266 - val_acc: 0.2381
# Epoch 13/100
# 384/385 [============================>.] - ETA: 0s - loss: -3089.6130 - acc: 0.2326
# Epoch 00013: val_acc did not improve from 0.23912
# 385/385 [==============================] - 19s 49ms/step - loss: -3090.0723 - acc: 0.2325 - val_loss: -3127.2620 - val_acc: 0.2352
# Epoch 14/100
# 385/385 [==============================] - ETA: 0s - loss: -3201.1274 - acc: 0.2325
# Epoch 00014: val_acc improved from 0.23912 to 0.23977, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -3201.1274 - acc: 0.2325 - val_loss: -3234.0999 - val_acc: 0.2398
# Epoch 15/100
# 384/385 [============================>.] - ETA: 0s - loss: -3314.0310 - acc: 0.2338
# Epoch 00015: val_acc did not improve from 0.23977
# 385/385 [==============================] - 19s 49ms/step - loss: -3313.6646 - acc: 0.2338 - val_loss: -3340.9148 - val_acc: 0.2318
# Epoch 16/100
# 384/385 [============================>.] - ETA: 0s - loss: -3425.3542 - acc: 0.2321
# Epoch 00016: val_acc did not improve from 0.23977
# 385/385 [==============================] - 19s 49ms/step - loss: -3424.8979 - acc: 0.2323 - val_loss: -3459.0874 - val_acc: 0.2362
# Epoch 17/100
# 385/385 [==============================] - ETA: 0s - loss: -3535.3721 - acc: 0.2338
# Epoch 00017: val_acc improved from 0.23977 to 0.24025, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -3535.3721 - acc: 0.2338 - val_loss: -3568.5620 - val_acc: 0.2403
# Epoch 18/100
# 384/385 [============================>.] - ETA: 0s - loss: -3647.3245 - acc: 0.2338
# Epoch 00018: val_acc did not improve from 0.24025
# 385/385 [==============================] - 19s 49ms/step - loss: -3647.4773 - acc: 0.2339 - val_loss: -3680.3967 - val_acc: 0.2326
# Epoch 19/100
# 385/385 [==============================] - ETA: 0s - loss: -3759.8425 - acc: 0.2345
# Epoch 00019: val_acc did not improve from 0.24025
# 385/385 [==============================] - 19s 49ms/step - loss: -3759.8425 - acc: 0.2345 - val_loss: -3791.1084 - val_acc: 0.2318
# Epoch 20/100
# 385/385 [==============================] - ETA: 0s - loss: -3871.4470 - acc: 0.2345
# Epoch 00020: val_acc did not improve from 0.24025
# 385/385 [==============================] - 19s 49ms/step - loss: -3871.4470 - acc: 0.2345 - val_loss: -3899.7788 - val_acc: 0.2403
# Epoch 21/100
# 384/385 [============================>.] - ETA: 0s - loss: -3982.6868 - acc: 0.2345
# Epoch 00021: val_acc improved from 0.24025 to 0.24172, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -3981.9265 - acc: 0.2348 - val_loss: -4007.8533 - val_acc: 0.2417
# Epoch 22/100
# 385/385 [==============================] - ETA: 0s - loss: -4093.8489 - acc: 0.2351
# Epoch 00022: val_acc did not improve from 0.24172
# 385/385 [==============================] - 19s 49ms/step - loss: -4093.8489 - acc: 0.2351 - val_loss: -4118.1572 - val_acc: 0.2360
# Epoch 23/100
# 384/385 [============================>.] - ETA: 0s - loss: -4206.9141 - acc: 0.2322
# Epoch 00023: val_acc did not improve from 0.24172
# 385/385 [==============================] - 19s 49ms/step - loss: -4205.7974 - acc: 0.2323 - val_loss: -4233.6699 - val_acc: 0.2380
# Epoch 24/100
# 384/385 [============================>.] - ETA: 0s - loss: -4316.8442 - acc: 0.2348
# Epoch 00024: val_acc did not improve from 0.24172
# 385/385 [==============================] - 19s 49ms/step - loss: -4317.9902 - acc: 0.2348 - val_loss: -4324.5952 - val_acc: 0.2406
# Epoch 25/100
# 384/385 [============================>.] - ETA: 0s - loss: -4429.8247 - acc: 0.2344
# Epoch 00025: val_acc did not improve from 0.24172
# 385/385 [==============================] - 19s 50ms/step - loss: -4430.1782 - acc: 0.2343 - val_loss: -4453.3750 - val_acc: 0.2264
# Epoch 26/100
# 385/385 [==============================] - ETA: 0s - loss: -4541.2720 - acc: 0.2336
# Epoch 00026: val_acc improved from 0.24172 to 0.24301, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -4541.2720 - acc: 0.2336 - val_loss: -4555.6890 - val_acc: 0.2430
# Epoch 27/100
# 384/385 [============================>.] - ETA: 0s - loss: -4650.1538 - acc: 0.2356
# Epoch 00027: val_acc did not improve from 0.24301
# 385/385 [==============================] - 19s 49ms/step - loss: -4651.9678 - acc: 0.2355 - val_loss: -4661.0918 - val_acc: 0.2381
# Epoch 28/100
# 384/385 [============================>.] - ETA: 0s - loss: -4764.9302 - acc: 0.2358
# Epoch 00028: val_acc did not improve from 0.24301
# 385/385 [==============================] - 19s 49ms/step - loss: -4763.6191 - acc: 0.2359 - val_loss: -4783.7168 - val_acc: 0.2399
# Epoch 29/100
# 385/385 [==============================] - ETA: 0s - loss: -4876.7554 - acc: 0.2346
# Epoch 00029: val_acc did not improve from 0.24301
# 385/385 [==============================] - 19s 49ms/step - loss: -4876.7554 - acc: 0.2346 - val_loss: -4896.8101 - val_acc: 0.2401
# Epoch 30/100
# 385/385 [==============================] - ETA: 0s - loss: -4985.6675 - acc: 0.2354
# Epoch 00030: val_acc did not improve from 0.24301
# 385/385 [==============================] - 19s 50ms/step - loss: -4985.6675 - acc: 0.2354 - val_loss: -5001.7261 - val_acc: 0.2367
# Epoch 31/100
# 384/385 [============================>.] - ETA: 0s - loss: -5098.6841 - acc: 0.2340
# Epoch 00031: val_acc improved from 0.24301 to 0.24594, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -5099.4619 - acc: 0.2339 - val_loss: -5104.7573 - val_acc: 0.2459
# Epoch 32/100
# 385/385 [==============================] - ETA: 0s - loss: -5209.9380 - acc: 0.2374
# Epoch 00032: val_acc did not improve from 0.24594
# 385/385 [==============================] - 19s 49ms/step - loss: -5209.9380 - acc: 0.2374 - val_loss: -5206.0601 - val_acc: 0.2386
# Epoch 33/100
# 384/385 [============================>.] - ETA: 0s - loss: -5321.5376 - acc: 0.2349
# Epoch 00033: val_acc did not improve from 0.24594
# 385/385 [==============================] - 19s 49ms/step - loss: -5321.1636 - acc: 0.2352 - val_loss: -5336.9180 - val_acc: 0.2377
# Epoch 34/100
# 385/385 [==============================] - ETA: 0s - loss: -5433.3472 - acc: 0.2371
# Epoch 00034: val_acc improved from 0.24594 to 0.24773, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -5433.3472 - acc: 0.2371 - val_loss: -5424.7075 - val_acc: 0.2477
# Epoch 35/100
# 385/385 [==============================] - ETA: 0s - loss: -5544.5435 - acc: 0.2371
# Epoch 00035: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -5544.5435 - acc: 0.2371 - val_loss: -5555.6968 - val_acc: 0.2406
# Epoch 36/100
# 385/385 [==============================] - ETA: 0s - loss: -5656.4888 - acc: 0.2347
# Epoch 00036: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -5656.4888 - acc: 0.2347 - val_loss: -5662.2461 - val_acc: 0.2435
# Epoch 37/100
# 384/385 [============================>.] - ETA: 0s - loss: -5769.7539 - acc: 0.2366
# Epoch 00037: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -5768.5547 - acc: 0.2366 - val_loss: -5762.0864 - val_acc: 0.2425
# Epoch 38/100
# 384/385 [============================>.] - ETA: 0s - loss: -5879.6250 - acc: 0.2360
# Epoch 00038: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -5879.8379 - acc: 0.2360 - val_loss: -5889.5674 - val_acc: 0.2399
# Epoch 39/100
# 384/385 [============================>.] - ETA: 0s - loss: -5995.9805 - acc: 0.2361
# Epoch 00039: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -5993.2471 - acc: 0.2362 - val_loss: -6003.7480 - val_acc: 0.2365
# Epoch 40/100
# 384/385 [============================>.] - ETA: 0s - loss: -6099.8638 - acc: 0.2350
# Epoch 00040: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -6102.9756 - acc: 0.2348 - val_loss: -6110.5073 - val_acc: 0.2342
# Epoch 41/100
# 384/385 [============================>.] - ETA: 0s - loss: -6215.8999 - acc: 0.2357
# Epoch 00041: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 50ms/step - loss: -6216.5708 - acc: 0.2357 - val_loss: -6225.5166 - val_acc: 0.2253
# Epoch 42/100
# 385/385 [==============================] - ETA: 0s - loss: -6327.9731 - acc: 0.2365
# Epoch 00042: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 50ms/step - loss: -6327.9731 - acc: 0.2365 - val_loss: -6334.5596 - val_acc: 0.2297
# Epoch 43/100
# 384/385 [============================>.] - ETA: 0s - loss: -6438.1753 - acc: 0.2362
# Epoch 00043: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 50ms/step - loss: -6438.0488 - acc: 0.2361 - val_loss: -6438.7188 - val_acc: 0.2372
# Epoch 44/100
# 385/385 [==============================] - ETA: 0s - loss: -6550.2266 - acc: 0.2361
# Epoch 00044: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -6550.2266 - acc: 0.2361 - val_loss: -6546.3706 - val_acc: 0.2380
# Epoch 45/100
# 385/385 [==============================] - ETA: 0s - loss: -6662.7827 - acc: 0.2359
# Epoch 00045: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 50ms/step - loss: -6662.7827 - acc: 0.2359 - val_loss: -6664.1880 - val_acc: 0.2308
# Epoch 46/100
# 384/385 [============================>.] - ETA: 0s - loss: -6777.8906 - acc: 0.2362
# Epoch 00046: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 49ms/step - loss: -6776.2695 - acc: 0.2365 - val_loss: -6777.0825 - val_acc: 0.2360
# Epoch 47/100
# 384/385 [============================>.] - ETA: 0s - loss: -6890.7759 - acc: 0.2359
# Epoch 00047: val_acc did not improve from 0.24773
# 385/385 [==============================] - 19s 50ms/step - loss: -6886.7383 - acc: 0.2362 - val_loss: -6879.4180 - val_acc: 0.2403
# Epoch 48/100
# 384/385 [============================>.] - ETA: 0s - loss: -6999.5972 - acc: 0.2371
# Epoch 00048: val_acc improved from 0.24773 to 0.24935, saving model to best_model.h5
# 385/385 [==============================] - 19s 49ms/step - loss: -6999.9380 - acc: 0.2371 - val_loss: -6957.8770 - val_acc: 0.2494
# Epoch 49/100
# 385/385 [==============================] - ETA: 0s - loss: -7110.7754 - acc: 0.2384
# Epoch 00049: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 49ms/step - loss: -7110.7754 - acc: 0.2384 - val_loss: -7105.6069 - val_acc: 0.2354
# Epoch 50/100
# 384/385 [============================>.] - ETA: 0s - loss: -7226.1245 - acc: 0.2372
# Epoch 00050: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 49ms/step - loss: -7224.5337 - acc: 0.2374 - val_loss: -7208.9868 - val_acc: 0.2381
# Epoch 51/100
# 384/385 [============================>.] - ETA: 0s - loss: -7334.0469 - acc: 0.2376
# Epoch 00051: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -7336.4229 - acc: 0.2375 - val_loss: -7331.9429 - val_acc: 0.2346
# Epoch 52/100
# 384/385 [============================>.] - ETA: 0s - loss: -7448.7993 - acc: 0.2369
# Epoch 00052: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -7446.8643 - acc: 0.2370 - val_loss: -7433.4614 - val_acc: 0.2385
# Epoch 53/100
# 385/385 [==============================] - ETA: 0s - loss: -7559.0815 - acc: 0.2395
# Epoch 00053: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 49ms/step - loss: -7559.0815 - acc: 0.2395 - val_loss: -7546.2246 - val_acc: 0.2333
# Epoch 54/100
# 384/385 [============================>.] - ETA: 0s - loss: -7671.5874 - acc: 0.2383
# Epoch 00054: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -7670.8301 - acc: 0.2385 - val_loss: -7649.9653 - val_acc: 0.2381
# Epoch 55/100
# 384/385 [============================>.] - ETA: 0s - loss: -7785.6040 - acc: 0.2388
# Epoch 00055: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -7782.8789 - acc: 0.2389 - val_loss: -7771.3374 - val_acc: 0.2316
# Epoch 56/100
# 384/385 [============================>.] - ETA: 0s - loss: -7893.0000 - acc: 0.2375
# Epoch 00056: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -7895.0537 - acc: 0.2375 - val_loss: -7883.3916 - val_acc: 0.2396
# Epoch 57/100
# 385/385 [==============================] - ETA: 0s - loss: -8007.9263 - acc: 0.2384
# Epoch 00057: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8007.9263 - acc: 0.2384 - val_loss: -7991.6562 - val_acc: 0.2388
# Epoch 58/100
# 384/385 [============================>.] - ETA: 0s - loss: -8120.1333 - acc: 0.2382
# Epoch 00058: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8120.8882 - acc: 0.2381 - val_loss: -8090.5366 - val_acc: 0.2401
# Epoch 59/100
# 385/385 [==============================] - ETA: 0s - loss: -8230.4902 - acc: 0.2394
# Epoch 00059: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8230.4902 - acc: 0.2394 - val_loss: -8203.0635 - val_acc: 0.2398
# Epoch 60/100
# 384/385 [============================>.] - ETA: 0s - loss: -8343.9932 - acc: 0.2375
# Epoch 00060: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8344.2852 - acc: 0.2375 - val_loss: -8319.0879 - val_acc: 0.2383
# Epoch 61/100
# 385/385 [==============================] - ETA: 0s - loss: -8455.8652 - acc: 0.2384
# Epoch 00061: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8455.8652 - acc: 0.2384 - val_loss: -8416.5508 - val_acc: 0.2406
# Epoch 62/100
# 384/385 [============================>.] - ETA: 0s - loss: -8564.9805 - acc: 0.2398
# Epoch 00062: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8567.0850 - acc: 0.2397 - val_loss: -8533.5254 - val_acc: 0.2401
# Epoch 63/100
# 384/385 [============================>.] - ETA: 0s - loss: -8685.6602 - acc: 0.2385
# Epoch 00063: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8680.3896 - acc: 0.2386 - val_loss: -8655.2871 - val_acc: 0.2258
# Epoch 64/100
# 384/385 [============================>.] - ETA: 0s - loss: -8794.5068 - acc: 0.2384
# Epoch 00064: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8790.7617 - acc: 0.2388 - val_loss: -8762.1445 - val_acc: 0.2388
# Epoch 65/100
# 384/385 [============================>.] - ETA: 0s - loss: -8903.1846 - acc: 0.2402
# Epoch 00065: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -8905.3096 - acc: 0.2399 - val_loss: -8877.1924 - val_acc: 0.2279
# Epoch 66/100
# 385/385 [==============================] - ETA: 0s - loss: -9013.7227 - acc: 0.2379
# Epoch 00066: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9013.7227 - acc: 0.2379 - val_loss: -8971.2900 - val_acc: 0.2411
# Epoch 67/100
# 384/385 [============================>.] - ETA: 0s - loss: -9128.4980 - acc: 0.2406
# Epoch 00067: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9128.4873 - acc: 0.2406 - val_loss: -9069.8418 - val_acc: 0.2458
# Epoch 68/100
# 385/385 [==============================] - ETA: 0s - loss: -9241.6191 - acc: 0.2395
# Epoch 00068: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9241.6191 - acc: 0.2395 - val_loss: -9208.8906 - val_acc: 0.2331
# Epoch 69/100
# 385/385 [==============================] - ETA: 0s - loss: -9352.8506 - acc: 0.2383
# Epoch 00069: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9352.8506 - acc: 0.2383 - val_loss: -9300.5088 - val_acc: 0.2390
# Epoch 70/100
# 385/385 [==============================] - ETA: 0s - loss: -9463.2139 - acc: 0.2397
# Epoch 00070: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9463.2139 - acc: 0.2397 - val_loss: -9416.9482 - val_acc: 0.2406
# Epoch 71/100
# 384/385 [============================>.] - ETA: 0s - loss: -9574.6865 - acc: 0.2414
# Epoch 00071: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9577.8779 - acc: 0.2413 - val_loss: -9541.7480 - val_acc: 0.2328
# Epoch 72/100
# 384/385 [============================>.] - ETA: 0s - loss: -9685.5068 - acc: 0.2395
# Epoch 00072: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9688.9102 - acc: 0.2394 - val_loss: -9632.8691 - val_acc: 0.2417
# Epoch 73/100
# 384/385 [============================>.] - ETA: 0s - loss: -9803.7979 - acc: 0.2403
# Epoch 00073: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9801.3320 - acc: 0.2404 - val_loss: -9752.8281 - val_acc: 0.2390
# Epoch 74/100
# 385/385 [==============================] - ETA: 0s - loss: -9911.4424 - acc: 0.2403
# Epoch 00074: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -9911.4424 - acc: 0.2403 - val_loss: -9862.4414 - val_acc: 0.2409
# Epoch 75/100
# 384/385 [============================>.] - ETA: 0s - loss: -10023.4072 - acc: 0.2398
# Epoch 00075: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10023.3105 - acc: 0.2397 - val_loss: -9953.4961 - val_acc: 0.2443
# Epoch 76/100
# 384/385 [============================>.] - ETA: 0s - loss: -10133.4521 - acc: 0.2417
# Epoch 00076: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10136.0576 - acc: 0.2416 - val_loss: -10082.5449 - val_acc: 0.2328
# Epoch 77/100
# 385/385 [==============================] - ETA: 0s - loss: -10247.7754 - acc: 0.2393
# Epoch 00077: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10247.7754 - acc: 0.2393 - val_loss: -10168.7461 - val_acc: 0.2336
# Epoch 78/100
# 384/385 [============================>.] - ETA: 0s - loss: -10357.6201 - acc: 0.2391
# Epoch 00078: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10358.8125 - acc: 0.2392 - val_loss: -10304.0098 - val_acc: 0.2378
# Epoch 79/100
# 384/385 [============================>.] - ETA: 0s - loss: -10474.5654 - acc: 0.2412
# Epoch 00079: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10471.9746 - acc: 0.2413 - val_loss: -10404.6504 - val_acc: 0.2401
# Epoch 80/100
# 384/385 [============================>.] - ETA: 0s - loss: -10582.9678 - acc: 0.2407
# Epoch 00080: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10585.6797 - acc: 0.2405 - val_loss: -10511.6680 - val_acc: 0.2427
# Epoch 81/100
# 384/385 [============================>.] - ETA: 0s - loss: -10697.8447 - acc: 0.2413
# Epoch 00081: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10699.2852 - acc: 0.2412 - val_loss: -10649.1914 - val_acc: 0.2338
# Epoch 82/100
# 385/385 [==============================] - ETA: 0s - loss: -10808.9521 - acc: 0.2415
# Epoch 00082: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10808.9521 - acc: 0.2415 - val_loss: -10737.3232 - val_acc: 0.2359
# Epoch 83/100
# 385/385 [==============================] - ETA: 0s - loss: -10921.5908 - acc: 0.2407
# Epoch 00083: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -10921.5908 - acc: 0.2407 - val_loss: -10866.0088 - val_acc: 0.2381
# Epoch 84/100
# 384/385 [============================>.] - ETA: 0s - loss: -11029.3857 - acc: 0.2410
# Epoch 00084: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11033.2344 - acc: 0.2408 - val_loss: -10969.1855 - val_acc: 0.2386
# Epoch 85/100
# 385/385 [==============================] - ETA: 0s - loss: -11145.1982 - acc: 0.2427
# Epoch 00085: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11145.1982 - acc: 0.2427 - val_loss: -11054.2861 - val_acc: 0.2393
# Epoch 86/100
# 385/385 [==============================] - ETA: 0s - loss: -11257.8252 - acc: 0.2423
# Epoch 00086: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11257.8252 - acc: 0.2423 - val_loss: -11191.8770 - val_acc: 0.2377
# Epoch 87/100
# 384/385 [============================>.] - ETA: 0s - loss: -11367.7979 - acc: 0.2407
# Epoch 00087: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11367.9121 - acc: 0.2407 - val_loss: -11279.2412 - val_acc: 0.2399
# Epoch 88/100
# 384/385 [============================>.] - ETA: 0s - loss: -11483.5195 - acc: 0.2410
# Epoch 00088: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11481.7939 - acc: 0.2411 - val_loss: -11385.6348 - val_acc: 0.2390
# Epoch 89/100
# 384/385 [============================>.] - ETA: 0s - loss: -11592.8740 - acc: 0.2406
# Epoch 00089: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11592.7168 - acc: 0.2405 - val_loss: -11526.0957 - val_acc: 0.2411
# Epoch 90/100
# 384/385 [============================>.] - ETA: 0s - loss: -11707.6094 - acc: 0.2413
# Epoch 00090: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 51ms/step - loss: -11708.0645 - acc: 0.2412 - val_loss: -11645.2344 - val_acc: 0.2355
# Epoch 91/100
# 384/385 [============================>.] - ETA: 0s - loss: -11818.4150 - acc: 0.2422
# Epoch 00091: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11820.1660 - acc: 0.2422 - val_loss: -11722.2715 - val_acc: 0.2411
# Epoch 92/100
# 385/385 [==============================] - ETA: 0s - loss: -11929.5176 - acc: 0.2417
# Epoch 00092: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -11929.5176 - acc: 0.2417 - val_loss: -11856.3135 - val_acc: 0.2316
# Epoch 93/100
# 384/385 [============================>.] - ETA: 0s - loss: -12040.5381 - acc: 0.2413
# Epoch 00093: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 51ms/step - loss: -12040.9697 - acc: 0.2414 - val_loss: -11965.5430 - val_acc: 0.2362
# Epoch 94/100
# 385/385 [==============================] - ETA: 0s - loss: -12157.8896 - acc: 0.2428
# Epoch 00094: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12157.8896 - acc: 0.2428 - val_loss: -12067.8311 - val_acc: 0.2383
# Epoch 95/100
# 384/385 [============================>.] - ETA: 0s - loss: -12267.5469 - acc: 0.2419
# Epoch 00095: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12267.3633 - acc: 0.2419 - val_loss: -12173.2109 - val_acc: 0.2390
# Epoch 96/100
# 385/385 [==============================] - ETA: 0s - loss: -12379.5566 - acc: 0.2418
# Epoch 00096: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12379.5566 - acc: 0.2418 - val_loss: -12260.4482 - val_acc: 0.2388
# Epoch 97/100
# 384/385 [============================>.] - ETA: 0s - loss: -12493.5430 - acc: 0.2413
# Epoch 00097: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12492.9932 - acc: 0.2413 - val_loss: -12392.1973 - val_acc: 0.2352
# Epoch 98/100
# 384/385 [============================>.] - ETA: 0s - loss: -12610.2998 - acc: 0.2425
# Epoch 00098: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12605.6738 - acc: 0.2426 - val_loss: -12524.6592 - val_acc: 0.2344
# Epoch 99/100
# 384/385 [============================>.] - ETA: 0s - loss: -12715.2422 - acc: 0.2442
# Epoch 00099: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 51ms/step - loss: -12717.8008 - acc: 0.2442 - val_loss: -12626.4238 - val_acc: 0.2406
# Epoch 100/100
# 384/385 [============================>.] - ETA: 0s - loss: -12826.2080 - acc: 0.2411
# Epoch 00100: val_acc did not improve from 0.24935
# 385/385 [==============================] - 19s 50ms/step - loss: -12828.7402 - acc: 0.2410 - val_loss: -12725.3867 - val_acc: 0.2344

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(test_text, test_label)[1]))
# Out:
# 413/413 [==============================] - 4s 8ms/step - loss: -6887.8716 - acc: 0.2531
#
#  테스트 정확도: 0.2531

# %%
import re

def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  print(score)

# %%
sentiment_predict("권태긴줄 알았는데 다른 사람이 생겼나보더라고.")
# Out:
# 1.0
