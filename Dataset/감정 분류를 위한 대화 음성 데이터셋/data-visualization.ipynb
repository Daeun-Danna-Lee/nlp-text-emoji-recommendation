# %%
import pandas as pd
from pandas import DataFrame as df
import csv

# %%
# 파일 불러오기

df_4   = pd.read_csv('./4차년도.csv',encoding='cp949')
df_5   = pd.read_csv('./5차년도.csv',encoding='cp949')
df_5_2 = pd.read_csv('./5차년도_2차.csv',encoding='cp949')

# %%
merged_df = pd.concat([df_4, df_5, df_5_2])

# %%
data = merged_df.drop(columns=['wav_id', '나이', '성별'], axis=0)

# %%
data
# Out:
#                              발화문         상황      1번 감정  1번 감정세기    2번 감정  \
# 0               어, 청소 니가 대신 해 줘!      anger    Neutral        0    Angry
# 1             둘 다 청소 하기 싫어. 귀찮아.      anger    Neutral        0    Angry
# 2                 둘 다 하기 싫어서 화내.      anger      Angry        1    Angry
# 3                    그럼 방세는 어떡해.      anger    Sadness        1  Sadness
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.        sad    Sadness        1  Sadness
# ...                          ...        ...        ...      ...      ...
# 19369              나 엘리베이터에 갇혔어.       fear  happiness        1  sadness
# 19370          하지만 기분이 나쁜 걸 어떡해?      angry    sadness        1     fear
# 19371          자취방 엘리베이턴데 정전인가봐.       fear    sadness        1  neutral
# 19372            나 드디어 프로젝트 끝났어!  happiness    disgust        1  sadness
# 19373                 걱정해줘서 고마워.    disgust    neutral        0  neutral
#
#        2번 감정세기    3번 감정  3번 감정세기      4번 감정  4번감정세기    5번 감정  5번 감정세기
# 0            1  Neutral        0    Neutral       0    Angry        1
# 1            1  Neutral        0    Neutral       0    Angry        1
# 2            1  Neutral        0      Angry       1    Angry        1
# 3            1  Sadness        1    Sadness       1  Sadness        1
# 4            1  Sadness        1    Sadness       2  Sadness        1
# ...        ...      ...      ...        ...     ...      ...      ...
# 19369        1  sadness        2    sadness       1  sadness        1
# 19370        1  sadness        2    sadness       1  neutral        0
# 19371        0  sadness        2       fear       1  sadness        1
# 19372        1  neutral        0  happiness       1  sadness        1
# 19373        0  neutral        0    neutral       0  neutral        0
#
# [43991 rows x 12 columns]

# %%
emotion_dict = {'happy': 0, 'angry': 1, 'disgust': 2, 'fear': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
emotion_list = ['happiness', 'angry', 'disgust', 'fear', 'neutral', 'sadness', 'surprise']
emotions = [] # [happy, angry, disgust, fear, neutral, sad, surprise]

for row in data:
    if row[1] == '발화문':
        continue
    print(data)
    emotions = [0 for _ in range(7)]
    
    for i in range(3, 13, 2):
        print(row[i])
        emotions[emotion_list.index(row[i])] += 1
    
    data['평균감정'] = emotions.index(max(emotions))
    data['평균 감정세기'] = max(emotions)
# Out:
#               둘 다 청소 하기 싫어. 귀찮아.      anger    Neutral  0    Angry  1  \
# 1             둘 다 청소 하기 싫어. 귀찮아.      anger    Neutral  0    Angry  1
# 2                 둘 다 하기 싫어서 화내.      anger      Angry  1    Angry  1
# 3                    그럼 방세는 어떡해.      anger    Sadness  1  Sadness  1
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.        sad    Sadness  1  Sadness  1
# 5                      그냥 걷고 있어.        sad    Neutral  0  Neutral  0
# ...                          ...        ...        ... ..      ... ..
# 19369              나 엘리베이터에 갇혔어.       fear  happiness  1  sadness  1
# 19370          하지만 기분이 나쁜 걸 어떡해?      angry    sadness  1     fear  1
# 19371          자취방 엘리베이턴데 정전인가봐.       fear    sadness  1  neutral  0
# 19372            나 드디어 프로젝트 끝났어!  happiness    disgust  1  sadness  1
# 19373                 걱정해줘서 고마워.    disgust    neutral  0  neutral  0
#
#        Neutral  0    Neutral  0    Angry  1
# 1      Neutral  0    Neutral  0    Angry  1
# 2      Neutral  0      Angry  1    Angry  1
# 3      Sadness  1    Sadness  1  Sadness  1
# 4      Sadness  1    Sadness  2  Sadness  1
# 5      Neutral  0    Sadness  2  Neutral  0
# ...        ... ..        ... ..      ... ..
# 19369  sadness  2    sadness  1  sadness  1
# 19370  sadness  2    sadness  1  neutral  0
# 19371  sadness  2       fear  1  sadness  1
# 19372  neutral  0  happiness  1  sadness  1
# 19373  neutral  0    neutral  0  neutral  0
#
# [43988 rows x 12 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-ce2598a2c73f> in <module>
#      11     for i in range(3, 13, 2):
#      12         print(row[i])
# ---> 13         emotions[emotion_list.index(row[i])] += 1
#      14
#      15     data['평균감정'] = emotions.index(max(emotions))
#
# ValueError: ' ' is not in list
