# %%
import pandas as pd
from pandas import DataFrame as df
import csv

# %% [markdown]
# ### 1. 감정 분류를 위한 대화 음성 데이터셋

# %%
# 파일 불러오기

df_4   = pd.read_csv('./4차년도.csv',encoding='cp949')
df_5   = pd.read_csv('./5차년도.csv',encoding='cp949')
df_5_2 = pd.read_csv('./5차년도_2차.csv',encoding='cp949')

# %%
# 모든 연도 데이터 합치기

merged_df = pd.concat([df_4, df_5, df_5_2])
merged_df = merged_df.reset_index()

# %%
# 필요 없는 column 삭제하기

data = merged_df.drop(columns=['index', 'wav_id', '나이', '성별', '상황'], axis=0)

# %%
data
# Out:
#                              발화문      1번 감정  1번 감정세기    2번 감정  2번 감정세기  \
# 0               어, 청소 니가 대신 해 줘!    Neutral        0    Angry        1
# 1             둘 다 청소 하기 싫어. 귀찮아.    Neutral        0    Angry        1
# 2                 둘 다 하기 싫어서 화내.      Angry        1    Angry        1
# 3                    그럼 방세는 어떡해.    Sadness        1  Sadness        1
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.    Sadness        1  Sadness        1
# ...                          ...        ...      ...      ...      ...
# 43986              나 엘리베이터에 갇혔어.  happiness        1  sadness        1
# 43987          하지만 기분이 나쁜 걸 어떡해?    sadness        1     fear        1
# 43988          자취방 엘리베이턴데 정전인가봐.    sadness        1  neutral        0
# 43989            나 드디어 프로젝트 끝났어!    disgust        1  sadness        1
# 43990                 걱정해줘서 고마워.    neutral        0  neutral        0
#
#          3번 감정  3번 감정세기      4번 감정  4번감정세기    5번 감정  5번 감정세기
# 0      Neutral        0    Neutral       0    Angry        1
# 1      Neutral        0    Neutral       0    Angry        1
# 2      Neutral        0      Angry       1    Angry        1
# 3      Sadness        1    Sadness       1  Sadness        1
# 4      Sadness        1    Sadness       2  Sadness        1
# ...        ...      ...        ...     ...      ...      ...
# 43986  sadness        2    sadness       1  sadness        1
# 43987  sadness        2    sadness       1  neutral        0
# 43988  sadness        2       fear       1  sadness        1
# 43989  neutral        0  happiness       1  sadness        1
# 43990  neutral        0    neutral       0  neutral        0
#
# [43991 rows x 11 columns]

# %%
# 통합된 하나의 감정 추출하기

emotion_dict = {'happy': 0, 'angry': 1, 'disgust': 2, 'fear': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
emotion_list = ['happiness', 'angry', 'disgust', 'fear', 'neutral', 'sadness', 'surprise']
emotions = [] # [happy, angry, disgust, fear, neutral, sad, surprise]

for i in range(len(data)):
    emotions = [0 for _ in range(7)]
    
    for j in range(1, 10, 2):
        emotions[emotion_list.index(data.iloc[i, j].lower())] += 1
    
#     data.loc[i, '평균감정'] = emotion_list[emotions.index(max(emotions))] # 글자로
    data.loc[i, '평균감정'] = emotions.index(max(emotions)) # 숫자로

# %%
data
# Out:
#                              발화문      1번 감정  1번 감정세기    2번 감정  2번 감정세기  \
# 0               어, 청소 니가 대신 해 줘!    Neutral        0    Angry        1
# 1             둘 다 청소 하기 싫어. 귀찮아.    Neutral        0    Angry        1
# 2                 둘 다 하기 싫어서 화내.      Angry        1    Angry        1
# 3                    그럼 방세는 어떡해.    Sadness        1  Sadness        1
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.    Sadness        1  Sadness        1
# ...                          ...        ...      ...      ...      ...
# 43986              나 엘리베이터에 갇혔어.  happiness        1  sadness        1
# 43987          하지만 기분이 나쁜 걸 어떡해?    sadness        1     fear        1
# 43988          자취방 엘리베이턴데 정전인가봐.    sadness        1  neutral        0
# 43989            나 드디어 프로젝트 끝났어!    disgust        1  sadness        1
# 43990                 걱정해줘서 고마워.    neutral        0  neutral        0
#
#          3번 감정  3번 감정세기      4번 감정  4번감정세기    5번 감정  5번 감정세기  평균감정
# 0      Neutral        0    Neutral       0    Angry        1   4.0
# 1      Neutral        0    Neutral       0    Angry        1   4.0
# 2      Neutral        0      Angry       1    Angry        1   1.0
# 3      Sadness        1    Sadness       1  Sadness        1   5.0
# 4      Sadness        1    Sadness       2  Sadness        1   5.0
# ...        ...      ...        ...     ...      ...      ...   ...
# 43986  sadness        2    sadness       1  sadness        1   5.0
# 43987  sadness        2    sadness       1  neutral        0   5.0
# 43988  sadness        2       fear       1  sadness        1   5.0
# 43989  neutral        0  happiness       1  sadness        1   5.0
# 43990  neutral        0    neutral       0  neutral        0   4.0
#
# [43991 rows x 12 columns]

# %%
# 필요 없는 column 삭제하기

data = data.drop(columns=['1번 감정', '1번 감정세기', '2번 감정', '2번 감정세기', '3번 감정', '3번 감정세기', '4번 감정', '4번감정세기', '5번 감정', '5번 감정세기'], axis=0)
data
# Out:
#                              발화문  평균감정
# 0               어, 청소 니가 대신 해 줘!   4.0
# 1             둘 다 청소 하기 싫어. 귀찮아.   4.0
# 2                 둘 다 하기 싫어서 화내.   1.0
# 3                    그럼 방세는 어떡해.   5.0
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.   5.0
# ...                          ...   ...
# 43986              나 엘리베이터에 갇혔어.   5.0
# 43987          하지만 기분이 나쁜 걸 어떡해?   5.0
# 43988          자취방 엘리베이턴데 정전인가봐.   5.0
# 43989            나 드디어 프로젝트 끝났어!   5.0
# 43990                 걱정해줘서 고마워.   4.0
#
# [43991 rows x 2 columns]

# %%
# 데이터 저장

path = './processed_data'
data.to_csv(path , sep=',' , header=None , index=None)

# %%
data
# Out:
#                              발화문  평균감정
# 0               어, 청소 니가 대신 해 줘!   4.0
# 1             둘 다 청소 하기 싫어. 귀찮아.   4.0
# 2                 둘 다 하기 싫어서 화내.   1.0
# 3                    그럼 방세는 어떡해.   5.0
# 4      권태긴줄 알았는데 다른 사람이 생겼나보더라고.   5.0
# ...                          ...   ...
# 43986              나 엘리베이터에 갇혔어.   5.0
# 43987          하지만 기분이 나쁜 걸 어떡해?   5.0
# 43988          자취방 엘리베이턴데 정전인가봐.   5.0
# 43989            나 드디어 프로젝트 끝났어!   5.0
# 43990                 걱정해줘서 고마워.   4.0
#
# [43991 rows x 2 columns]

# %% [markdown]
# ### 2. 한국어 감정 정보가 포함된 단발성 대화 데이터셋

# %%
# 데이터 불러오기

df_short = pd.read_csv('./한국어_단발성_대화_데이터셋.csv',encoding='cp949')

# %%
df_short
# Out:
#                          wav_id  \
# 0      5e258fd1305bcf3ad153a6a4
# 1      5e258fe2305bcf3ad153a6a5
# 2      5e258ff5305bcf3ad153a6a6
# 3      5e25902f305bcf3ad153a6a9
# 4      5e27f90b5807b852d9e0157b
# ...                         ...
# 14601  5e53d6067bef803b4851dfc6
# 14602  5e53d61cc38c123b9ec6dde6
# 14603  5e53d6332a2d173b73a03210
# 14604  5e53d659963e443aee02b7d0
# 14605  5e53d6778849ac3aacea576f
#
#                                                      발화문     상황    1번 감정  \
# 0                                       어, 청소 니가 대신 해 줘!  anger  Neutral
# 1                                     둘 다 청소 하기 싫어. 귀찮아.  anger  Neutral
# 2                                         둘 다 하기 싫어서 화내.  anger    Angry
# 3                                            그럼 방세는 어떡해.  anger  Sadness
# 4                              권태긴줄 알았는데 다른 사람이 생겼나보더라고.    sad  Sadness
# ...                                                  ...    ...      ...
# 14601                             아, 요즘 룸메랑 너무 자주 싸우게 돼.  anger  Disgust
# 14602                  아, 룸메가 방을 너무 지저분하게 써. 음식물도 막 버리고.  anger  Disgust
# 14603  뭐 화를 낸 것까진 아니지만, 한 달 전 쯤에 좀 확실하게 얘기를 해뒀거든. 근데 ...  anger  Disgust
# 14604            어. 고등학교 동창인데, 같은 동네 오게 돼서 같이 룸메로 살게 됐지.  anger  Neutral
# 14605                                      그게 확실한 방법이겠지?  anger  Neutral
#
#        1번 감정세기    2번 감정  2번 감정세기    3번 감정  3번 감정세기    4번 감정  4번감정세기    5번 감정  \
# 0            0    Angry        1  Neutral        0  Neutral       0    Angry
# 1            0    Angry        1  Neutral        0  Neutral       0    Angry
# 2            1    Angry        1  Neutral        0    Angry       1    Angry
# 3            1  Sadness        1  Sadness        1  Sadness       1  Sadness
# 4            1  Sadness        1  Sadness        1  Sadness       2  Sadness
# ...        ...      ...      ...      ...      ...      ...     ...      ...
# 14601        1    Angry        2    Angry        1  Disgust       1    Angry
# 14602        1    Angry        2    Angry        1  Disgust       1    Angry
# 14603        1    Angry        2  Sadness        1  Disgust       1    Angry
# 14604        0    Angry        1  Sadness        1  Neutral       0  Neutral
# 14605        0    Angry        1  Sadness        1  Disgust       1  Neutral
#
#        5번 감정세기  나이    성별
# 0            1  27  male
# 1            1  27  male
# 2            1  27  male
# 3            1  27  male
# 4            1  32  male
# ...        ...  ..   ...
# 14601        1  35  male
# 14602        1  35  male
# 14603        2  35  male
# 14604        0  35  male
# 14605        0  35  male
#
# [14606 rows x 15 columns]
